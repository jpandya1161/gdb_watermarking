# %%
from py2neo import Graph

try:
    graph = Graph("neo4j://localhost:7687", auth=("neo4j", "Password"))
    result = graph.run("MATCH (n) RETURN n LIMIT 1")
    print("Connection successful. Data:", result.data())
except Exception as e:
    print("Failed to connect to Neo4j:", str(e))
# Out:
# Connection successful. Data: [{'n': Node('Company', companyNumber='09015410')}]

# %%
from py2neo import Graph
import random
import pandas as pd
from pandas import json_normalize
import hashlib

def create_groups_for_node(nodes_dict, min_length, max_length, total_length):
    groups = []
    remaining_records = total_length
    # print("HI")
    while groups == []:
        # print("HI")
        remaining_records = total_length
        while remaining_records > 0:
            
            # Set the max possible group size as the minimum of max_length or remaining_records
            max_possible_size = min(max_length, remaining_records)

            # print(min_length, max_possible_size)

            try:

                # Randomly choose a group size between min_length and max_possible_size
                group_size = random.randint(min_length, max_possible_size)

            except ValueError:
                break

            # Append the group size and reduce the remaining records
            groups.append(group_size)
            remaining_records -= group_size

            # Check if the remaining records would violate the constraints if left as a single group
            if remaining_records < min_length and remaining_records > 0:
                # Adjust the last group to absorb the remainder if possible
                if groups[-1] + remaining_records <= max_length:
                    groups[-1] += remaining_records
                    remaining_records = 0
                # else:
            #     return []  # Not possible to meet requirements

    return groups

def create_groups(dicts, group_sizes):
    grouped_dicts = []
    index = 0

    for size in group_sizes:
        group = dicts[index:index + size]  # Create a group of size 'size'
        grouped_dicts.append(group)
        index += size  # Move the index forward by 'size' for the next group

    return grouped_dicts

def create_pseudo_node(node_type, type_dicts_df, required_fields, optional_fields):
    pseudo_node = {}
    # pseudo_node = {"labels": node_type}
    # dicts_df = json_normalize(dicts, sep='_')
    # type_dicts_df = dicts_df[dicts_df['labels'] == node_type] # change the key as per the query

    for required_field in required_fields:
        req_fields_list = type_dicts_df[type_dicts_df[required_field].notna()][required_field].unique().tolist()
        req_field_val = random.choice(req_fields_list)
        pseudo_node[required_field] = req_field_val

    # search for all distinct values of the required fields and choose one for the pseudo-node

    # randomly decide on which optional fields to choose, search for all distinct values for each of the optional fields and then choose one
    opt_fields_num = random.randint(1, len(optional_fields))

    # Randomly choose the selected number of elements from the list (without duplicates)
    random_opt_fields = random.sample(optional_fields, opt_fields_num)

    for optional_field in random_opt_fields:
        opt_fields_list = type_dicts_df[type_dicts_df[optional_field].notna()][optional_field].unique().tolist()
        opt_field_val = random.choice(opt_fields_list)
        pseudo_node[optional_field] = opt_field_val

    return pseudo_node

# %%
query = """
MATCH (variable:Person)
RETURN variable
"""

result = graph.run(query)
nodes_as_dicts = [dict(record['variable']) for record in result]
# Out:
# [{'birthMonth': '2', 'nationality': 'American', 'birthYear': '1968', 'name': 'Mr. Charles Perlitz Kempf', 'countryOfResidence': 'England'}, {'birthMonth': '9', 'nationality': 'American', 'birthYear': '1964', 'name': 'Mr. William Howard Wolf Jr', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1962', 'name': 'Mrs Alison Shure', 'countryOfResidence': 'United States'}, {'birthMonth': '12', 'nationality': 'American', 'birthYear': '1961', 'name': 'Mr Stuart Mills', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1971', 'name': 'Mrs Vivienne Cleary Spoerri', 'countryOfResidence': 'England'}]

# %%
min_group_length = 1
max_group_length = 5
node_type = "PERSON"
dicts = nodes_as_dicts[:5000]

group_sizes = create_groups_for_node(dicts, min_group_length, max_group_length, len(dicts))
groups = create_groups(dicts, group_sizes)
# print(groups)
list_dict = {f"{i}": sublist for i, sublist in enumerate(groups)}
print(list_dict)

group_wise_pseudo_nodes = {}
dicts_df = pd.DataFrame(dicts)
# required_fields and optional_fields are to be decided after the manual analysis

# after creating groups, create pseudo node for every group of every node type
for key, _ in list_dict.items():
    pseudo_node = create_pseudo_node(node_type, dicts_df, required_fields=["birthMonth", "birthYear"], optional_fields=["nationality"])
    group_wise_pseudo_nodes[key] = pseudo_node

print(group_wise_pseudo_nodes)
# Out:
# {'0': [{'birthMonth': '2', 'nationality': 'American', 'birthYear': '1968', 'name': 'Mr. Charles Perlitz Kempf', 'countryOfResidence': 'England'}], '1': [{'birthMonth': '9', 'nationality': 'American', 'birthYear': '1964', 'name': 'Mr. William Howard Wolf Jr', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1962', 'name': 'Mrs Alison Shure', 'countryOfResidence': 'United States'}, {'birthMonth': '12', 'nationality': 'American', 'birthYear': '1961', 'name': 'Mr Stuart Mills', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1971', 'name': 'Mrs Vivienne Cleary Spoerri', 'countryOfResidence': 'England'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1948', 'name': 'Mr Floyd Eugene Greco', 'countryOfResidence': 'England'}], '2': [{'birthMonth': '12', 'nationality': 'American', 'birthYear': '1955', 'name': 'Mrs Sandra Elizabeth Emms', 'countryOfResidence': 'England'}, {'birthMonth': '5', 'nationality': 'American', 'birthYear': '1964', 'name': 'Mr. Donald Gayhardt', 'countryOfResidence': 'United States'}, {'birthMonth': '5', 'nationality': 'American', 'birthYear': '1980', 'name': 'Lawrence Cheung', 'countryOfResidence': 'Usa'}], '3': [{'birthMonth': '9', 'nationality': 'American', 'birthYear': '1958', 'name': 'Ms Lauran Bromley', 'countryOfResidence': 'United States'}], '4': [{'birthMonth': '12', 'nationality': 'American', 'birthYear': '1957', 'name': 'Mr Edwin Elbert', 'countryOfResidence': 'United States'}, {'birthMonth': '7', 'nationality': 'American', 'birthYear': '1967', 'name': 'Mr Michael Patrick Klein', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '12', 'nationality': 'American', 'birthYear': '1956', 'name': 'Mr Stephen Barsky', 'countryOfResidence': 'England'}], '5': [{'birthMonth': '2', 'nationality': 'American', 'birthYear': '1986', 'name': 'Mrs Lesley Rooke', 'countryOfResidence': 'England'}, {'birthMonth': '1', 'nationality': 'American', 'birthYear': '1955', 'name': 'Ms Anne Elizabeth Johnston', 'countryOfResidence': 'England'}, {'birthMonth': '12', 'nationality': 'American', 'birthYear': '1
 'American,Japanese'}, '15': {'birthMonth': '11', 'birthYear': '1990', 'nationality': 'United States Of America'}, '16': {'birthMonth': '5', 'birthYear': '1946', 'nationality': 'Israeli,American'}, '17': {'birthMonth': '10', 'birthYear': '1968', 'nationality': 'American & British'}, '18': {'birthMonth': '3', 'birthYear': '1947', 'nationality': 'American,French'}, '19': {'birthMonth': '4', 'birthYear': '1983', 'nationality': 'American,French'}, '20': {'birthMonth': '7', 'birthYear': '1952', 'nationality': 'American,Dutch'}, '21': {'birthMonth': '3', 'birthYear': '1933', 'nationality': 'English,American'}, '22': {'birthMonth': '10', 'birthYear': '1977', 'nationality': 'American/Italian'}, '23': {'birthMonth': '12', 'birthYear': '1974', 'nationality': 'Dual National- British/American'}, '24': {'birthMonth': '4', 'birthYear': '1926', 'nationality': 'American,Japanese'}, '25': {'birthMonth': '5', 'birthYear': '1935', 'nationality': 'Filipino,American'}, '26': {'birthMonth': '8', 'birthYear': '1922', 'nationality': 'American,Polish'}, '27': {'birthMonth': '8', 'birthYear': '2016', 'nationality': 'South African,American'}, '28': {'birthMonth': '12', 'birthYear': '1947', 'nationality': 'American,English'}, '29': {'birthMonth': '2', 'birthYear': '1979', 'nationality': 'Italian,American'}, '30': {'birthMonth': '10', 'birthYear': '1918', 'nationality': 'British American'}, '31': {'birthMonth': '7', 'birthYear': '1937', 'nationality': 'German,American'}, '32': {'birthMonth': '11', 'birthYear': '1937', 'nationality': 'American,French'}, '33': {'birthMonth': '5', 'birthYear': '1929', 'nationality': 'American,German'}, '34': {'birthMonth': '12', 'birthYear': '1985', 'nationality': 'Greek,American'}, '35': {'birthMonth': '11', 'birthYear': '1983', 'nationality': 'Israeli,American'}, '36': {'birthMonth': '9', 'birthYear': '1950', 'nationality': 'American With British Citzenship'}, '37': {'birthMonth': '7', 'birthYear': '1944', 'nationality': 'American & British'}, '38': {'birthMonth': '4', 'birthYear': '1943', 'nationality': 'British/American (Dual National)'}, '39': {'birthMonth': '10', 'birthYear': '1960', 'nationality': 'United States Of America'}, '40': {'birthMonth': '8', 'birthYear': '1957', 'nationality': 'Israeli,American'}, '41': {'birthMonth': '2', 'birthYear': '1930', 'nationality': 'British Citizen/ American Citizen'}, '42': {'birthMonth': '7', 'birthYear': '1974', 'nationality': 'Israeli,American'}, '43': {'birthMonth': '10', 'birthYear': '1922', 'nationality': 'British/American (Dual National)'}, '44': {'birthMonth': '12', 'birthYear': '1992', 'nationality': 'Italian-American'}, '45': {'birthMonth': '1', 'birthYear': '1997', 'nationality': 'American,German'}, '46': {'birthMonth': '6', 'birth ...

# %%
print(len(group_wise_pseudo_nodes))
# Out:
# 1655

# %%
private_key = "e8d3cba12a8d4c3b9a12f4e7c5d1a8f2"
print(len(private_key))

# Watermarking:
# need private key, identity, field to be watermarked, fields used while watermarking

def watermark_pseudo_node(pseudo_node, private_key, watermark_identity, attributes, max_num_fields):
    # wm_attribute is a numerical field of a pseudo-node
    # attributes is a list of all the attributes of the pseudo-node
    # watermark_identity = ?
    watermark_secret = watermark_identity + "".join(attributes) + private_key
    hashed_secret = hashlib.sha256(watermark_secret.encode("utf-8")).digest()
    hashed_secret_int = int.from_bytes(hashed_secret, byteorder="big") % max_num_fields
    pseudo_node["hashed_secret"] = hashed_secret_int
    pseudo_node["watermark_id"] = watermark_identity

    return pseudo_node
# Out:
# 32

# %%
# Parameters
n = len(group_wise_pseudo_nodes)
lower_limit = 1
upper_limit = 10000

# Generate n unique random numbers
unique_random_numbers = random.sample(range(lower_limit, upper_limit + 1), n)

print("Unique random numbers:", unique_random_numbers)

# Watermarking parameters
watermark_identity = unique_random_numbers
# private_key = "e8d3cba12a8d4c3b9a12f4e7c5d1a8f2"
max_num_fields = 1000

# Initialize an empty list to store the watermarked pseudo nodes
watermarked_pseudo_nodes = []

# Initialize a dictionary to store the mapping of unique random numbers to hashed watermarked values
id_list = {}

# Iterate through the pseudo nodes, apply watermarking, and store mappings
for i, node in enumerate(group_wise_pseudo_nodes):
    # Generate the watermarked node
    watermarked_node = watermark_pseudo_node(
        group_wise_pseudo_nodes[node],
        private_key,
        str(watermark_identity[i]),
        [str(group_wise_pseudo_nodes[node]["birthMonth"]), str(group_wise_pseudo_nodes[node]["birthYear"])],
        max_num_fields
    )
    # Append the watermarked node to the list
    watermarked_pseudo_nodes.append(watermarked_node)

    # Map the unique random number to its corresponding watermarked value (hashed)
    id_list[watermark_identity[i]] = watermarked_node['hashed_secret']  # Assuming `watermarked_node` is hashed

# Print the resulting id_list
print("ID List:")
for key, value in id_list.items():
    print(f"Unique Random Number: {key}, Hashed Watermarked Value: {value}")


# Append watermarked pseudo nodes to their respective groups in list_dict
for key, group in list_dict.items():
    # Retrieve the corresponding watermarked pseudo node
    watermarked_node = watermarked_pseudo_nodes[int(key)]

    # Add the watermarked node to the group
    group.append(watermarked_node)

# Print the updated list_dict
print("Updated list_dict with watermarked pseudo nodes:")
for group_key, group_value in list_dict.items():
    print(f"Group {group_key}: {group_value}")

from itertools import chain

# Flatten the list using itertools.chain
full_data = list(chain(*list_dict.values()))

# Now combined_data will be a single list with all records
print(full_data)
# Out:
# Unique random numbers: [4823, 8065, 7043, 2570, 7055, 3571, 6072, 7997, 553, 1547, 1222, 36, 8078, 905, 7874, 3774, 7263, 9567, 5165, 9576, 3332, 7865, 3018, 7343, 5559, 3055, 3731, 5000, 7534, 4826, 8998, 1978, 2911, 6044, 7430, 6840, 5372, 659, 5548, 1224, 163, 4449, 5179, 153, 9794, 3341, 161, 3355, 7476, 401, 8982, 3664, 3768, 5147, 5872, 7799, 4085, 6854, 9433, 4766, 7021, 2607, 501, 4665, 6161, 3825, 5907, 3099, 3813, 6124, 6099, 432, 5688, 1529, 3182, 4387, 3079, 4577, 463, 7485, 1124, 5202, 5383, 7630, 4122, 4400, 3750, 7178, 5721, 2564, 6379, 8707, 9910, 266, 239, 5198, 7648, 323, 213, 1784, 1661, 8272, 3120, 3868, 1898, 4696, 9137, 3473, 5472, 9275, 3366, 9194, 8916, 548, 3584, 8171, 4094, 6743, 7792, 2788, 7690, 7375, 1285, 6128, 
1338, 7349, 9563, 953, 4372, 4030, 7980, 5932, 2734, 2166, 8729, 6608, 761, 8090, 1430, 2936, 5423, 8837, 1614, 787, 9985, 7567, 6173, 4762, 7010, 69, 6880, 2849, 5466, 3822, 846, 6085, 2100, 6816, 3243, 6829, 2441, 53, 6567, 27, 8658, 1987, 8726, 3760, 4850, 8147, 9266, 5480, 6276, 4950, 226, 8448, 9295, 6706, 3714, 2176, 9272, 9379, 3548, 1086, 2099, 3392, 3097, 7973, 6289, 196, 4920, 3144, 1979, 8251, 580, 7487, 2881, 8012, 899, 8163, 7905, 4474, 8835, 4645, 9151, 7127, 1942, 5254, 2761, 5762, 1307, 9475, 5328, 6687, 5387, 3227, 8332, 7137, 2490, 4672, 8583, 4178, 4973, 8587, 7325, 4867, 696, 1339, 821, 9564, 2917, 4156, 2082, 4008, 5059, 5490, 6005, 8553, 1215, 7670, 1713, 221, 6539, 743, 7080, 7400, 6899, 5685, 1433, 7231, 6399, 1093, 6112, 3894, 4344, 6162, 9856, 5550, 6915, 7202, 3423, 8942, 7109, 5977, 9816, 7007, 1401, 7566, 1764, 7489, 9262, 9124, 8388, 2071, 2945, 1999, 3788, 912, 1383, 5544, 313, 540 ...
# ID List:
# Unique Random Number: 4823, Hashed Watermarked Value: 58
# Unique Random Number: 8065, Hashed Watermarked Value: 519
# Unique Random Number: 7043, Hashed Watermarked Value: 706
# Unique Random Number: 2570, Hashed Watermarked Value: 733
# Unique Random Number: 7055, Hashed Watermarked Value: 516
# Unique Random Number: 3571, Hashed Watermarked Value: 123
# Unique Random Number: 6072, Hashed Watermarked Value: 662
# Unique Random Number: 7997, Hashed Watermarked Value: 173
# Unique Random Number: 553, Hashed Watermarked Value: 736
# Unique Random Number: 1547, Hashed Watermarked Value: 306
# Unique Random Number: 1222, Hashed Watermarked Value: 417
# Unique Random Number: 36, Hashed Watermarked Value: 141
# Unique Random Number: 8078, Hashed Watermarked Value: 214
# Unique Random Number: 905, Hashed Watermarked Value: 761
# Unique Random Number: 7874, Hashed Watermarked Value: 316
# Unique Random Number: 3774, Hashed Watermarked Value: 537
# Unique Random Number: 7263, Hashed Watermarked Value: 323
# Unique Random Number: 9567, Hashed Watermarked Value: 529
# Unique Random Number: 5165, Hashed Watermarked Value: 377
# Unique Random Number: 9576, Hashed Watermarked Value: 95
# Unique Random Number: 3332, Hashed Watermarked Value: 179
# Unique Random Number: 7865, Hashed Watermarked Value: 386
# Unique Random Number: 3018, Hashed Watermarked Value: 335
# Unique Random Number: 7343, Hashed Watermarked Value: 991
# Unique Random Number: 5559, Hashed Watermarked Value: 795
# Unique Random Number: 3055, Hashed Watermarked Value: 535
# Unique Random Number: 3731, Hashed Watermarked Value: 538
# Unique Random Number: 5000, Hashed Watermarked Value: 248
# Unique Random Number: 7534, Hashed Watermarked Value: 294
# Unique Random Number: 4826, Hashed Watermarked Value: 821
# Unique Random Number: 8998, Hashed Watermarked Value: 157
# Unique Random Number: 1978, Hashed Watermarked Value: 273
# Unique Random Number: 2911, Hashed Watermarked Value: 995
# Unique Random Number: 6044, Hashed Watermarked Value: 505
# Unique Random Number: 7430, Hashed Watermarked Value: 270
# Unique Random Number: 6840, Hashed Watermarked Value: 754
# Unique Random Number: 5372, Hashed Watermarked Value: 302
# Unique Random Number: 659, Hashed Watermarked Value: 45
# Unique Random Number: 5548, Hashed Watermarked Value: 21
# Unique Random Number: 1224, Hashed Watermarked Value: 255
# Unique Random Number: 163, Hashed Watermarked Value: 987
# Unique Random Number: 4449, Hashed Watermarked Value: 577
# Unique Random Number: 5179, Hashed Watermarked Value: 274
# Unique Random Number: 153, Hashed Watermarked Value: 417
# Unique Random Number: 9794, Hashed Watermarked Value: 571
# Unique Random Number: 3341, Hashed Watermarked Value: 330
# Unique Random Number: 161, Hashed Watermarked Value: 217
# Unique Random Number: 3355, Hashed Watermarked Value: 1
# Unique Random Number: 7476, Hashed Watermarked Value: 564
# Unique Random Number: 401, Hashed Watermarked Value: 716
# Unique Random Number: 8982, Hashed Watermarked Value: 626
# Unique Random Number: 3664, Hashed Watermarked Value: 587
# Unique Random Number: 3768, Hashed Watermarked Value: 644
# Unique Random Number: 5147, Hashed Watermarked Value: 89
# Unique Random Number: 5872, Hashed Watermarked Value: 655
# Unique Random Number: 7799, Hashed Watermarked Value: 8
# Unique Random Number: 4085, Hashed Watermarked Value: 746
# Unique Random Number: 6854, Hashed Watermarked Value: 984
# Unique Random Number: 9433, Hashed Watermarked Value: 154
# Unique Random Number: 4766, Hashed Watermarked Value: 26
# Unique Random Number: 7021, Hashed Watermarked Value: 484
# Unique Random Number: 2607, Hashed Watermarked Value: 575
# Unique Random Number: 501, Hashed Watermarked Value: 322
# Unique Random Number: 4665, Hashed Watermarked Value: 350
# Unique Random Number: 6161, Hashed Watermarked Value: 113
# Unique Random Number: 3825, Hashed Watermarked Value: 825
# Unique Random Number: 5907, Hashed Watermarked Value: 948
# Unique Random Number: 3099, Hashed Watermarked Value: 692
# Unique Random Number: 3813, Hashed Watermarked Value: 547
# Unique Random Number: 6124, Hashed Watermarked Value: 481
# Unique Random Number: 6099, Hashed Watermarked Value: 817
# Unique Random Number: 432, Hashed Watermarked Value: 617
# Unique Random Number: 5688, Hashed Watermarked Value: 506
# Unique Random Number: 1529, Hashed Watermarked Value: 6
# Unique Random Number: 3182, Hashed Watermarked Value: 640
# Unique Random Number: 4387, Hashed Watermarked Value: 694
# Unique Random Number: 3079, Hashed Watermarked Value: 420
# Unique Random Number: 4577, Hashed Watermarked Value: 974
# Unique Random Number: 463, Hashed Watermarked Value: 407
# Unique Random Number: 7485, Hashed Watermarked Value: 451
# Unique Random Number: 1124, Hashed Watermarked Value: 712
# Unique Random Number: 5202, Hashed Watermarked Value: 450
# Unique Random Number: 5383, Hashed Watermarked Value: 495
# Unique Random Number: 7630, Hashed Watermarked Value: 734
# Unique Random Number: 4122, Hashed Watermarked Value: 91
# Unique Random Number: 4400, Hashed Watermarked Value: 791
# Unique Random Number: 3750, Hashed Watermarked Value: 229
# Unique Random Number: 7178, Hashed Watermarked Value: 786
# Unique Random Number: 9285, Hashed Watermarked Value: 112
# Unique Random Number: 1600, Hashed Watermarked Value: 673
# Unique Random Number: 4609, Hashed Watermarked Value: 484
# Unique Random Number: 7769, Hashed Watermarked Value: 523
# Unique Random Number: 2880, Hashed Watermarked Value: 750
# Unique Random Number: 4980, Hashed Watermarked Value: 466
# Unique Random Number: 7596, Hashed Watermarked Value: 289
# Unique Random Number: 185, Hashed Watermarked Value: 647
# Unique Random Number: 453, Hashed Watermarked Value: 880
# Unique Random Number: 4290, Hashed Watermarked Value: 960
# Unique Random Number: 8334, Hashed Watermarked Value: 299
# Unique Random Number: 2673, Hashed Watermarked Value: 657
# Unique Random Number: 2702, Hashed Watermarked Value: 496
# Unique Random Number: 5203, Hashed Watermarked Value: 928
# Unique Random Number: 8932, Hashed Watermarked Value: 949
# Unique Random Number: 8472, Hashed Watermarked Value: 672
# Unique Random Number: 1179, Hashed Watermarked Value: 218
# Unique Random Number: 5627, Hashed Watermarked Value: 161
# Unique Random Number: 50, Hashed Watermarked Value: 963
# Unique Random Number: 4492, Hashed Watermarked Value: 861
# Unique Random Number: 2359, Hashed Watermarked Value: 483
# Unique Random Number: 5820, Hashed Watermarked Value: 201
# Unique Random Number: 8249, Hashed Watermarked Value: 935
# Unique Random Number: 7027, Hashed Watermarked Value: 57
# Unique Random Number: 4797, Hashed Watermarked Value: 131
# Unique Random Number: 6172, Hashed Watermarked Value: 261
# Unique Random Number: 4239, Hashed Watermarked Value: 964
# Unique Random Number: 934, Hashed Watermarked Value: 356
# Unique Random Number: 522, Hashed Watermarked Value: 57
# Unique Random Number: 9479, Hashed Watermarked Value: 556
# Unique Random Number: 2414, Hashed Watermarked Value: 768
# Unique Random Number: 2060, Hashed Watermarked Value: 990
# Unique Random Number: 7941, Hashed Watermarked Value: 244
# Unique Random Number: 3680, Hashed Watermarked Value: 711
# Unique Random Number: 2830, Hashed Watermarked Value: 469
# Unique Random Number: 3852, Hashed Watermarked Value: 507
# Unique Random Number: 8152, Hashed Watermarked Value: 488
# Unique Random Number: 3854, Hashed Watermarked Value: 985
# Unique Random Number: 5632, Hashed Watermarked Value: 384
# Unique Random Number: 9857, Hashed Watermarked Value: 716
# Unique Random Number: 2375, Hashed Watermarked Value: 135
# Unique Random Number: 840, Hashed Watermarked Value: 837
# Unique Random Number: 8824, Hashed Watermarked Value: 119
# Unique Random Number: 7503, Hashed Watermarked Value: 60
# Unique Random Number: 9074, Hashed Watermarked Value: 76
# Unique Random Number: 433, Hashed Watermarked Value: 143
# Unique Random Number: 1287, Hashed Watermarked Value: 659
# Unique Random Number: 8318, Hashed Watermarked Value: 393
# Unique Random Number: 3781, Hashed Watermarked Value: 586
# Unique Random Number: 6090, Hashed Watermarked Value: 897
# Unique Random Number: 9801, Hashed Watermarked Value: 372
# Unique Random Number: 1983, Hashed Watermarked Value: 109
# Unique Random Number: 7044, Hashed Watermarked Value: 492
# Unique Random Number: 3447, Hashed Watermarked Value: 217
# Unique Random Number: 3991, Hashed Watermarked Value: 982
# Unique Random Number: 4922, Hashed Watermarked Value: 187
# Unique Random Number: 6509, Hashed Watermarked Value: 725
# Unique Random Number: 6688, Hashed Watermarked Value: 512
# Unique Random Number: 8027, Hashed Watermarked Value: 749
# Unique Random Number: 6417, Hashed Watermarked Value: 967
# Unique Random Number: 9195, Hashed Watermarked Value: 623
# Unique Random Number: 8610, Hashed Watermarked Value: 423
# Unique Random Number: 1526, Hashed Watermarked Value: 705
# Unique Random Number: 7780, Hashed Watermarked Value: 789
# Unique Random Number: 2448, Hashed Watermarked Value: 975
# Unique Random Number: 8247, Hashed Watermarked Value: 541
# Unique Random Number: 4844, Hashed Watermarked Value: 682
# Unique Random Number: 6301, Hashed Watermarked Value: 641
# Unique Random Number: 3602, Hashed Watermarked Value: 997
# Unique Random Number: 422, Hashed Watermarked Value: 136
# Unique Random Number: 1818, Hashed Watermarked Value: 965
# Unique Random Number: 535, Hashed Watermarked Value: 907
# Unique Random Number: 5733, Hashed Watermarked Value: 67
# Unique Random Number: 2957, Hashed Watermarked Value: 737
# Unique Random Number: 8879, Hashed Watermarked Value: 350
# Unique Random Number: 3824, Hashed Watermarked Value: 823
# Unique Random Number: 2057, Hashed Watermarked Value: 282
# Unique Random Number: 4560, Hashed Watermarked Value: 896
# Unique Random Number: 4270, Hashed Watermarked Value: 702
# Unique Random Number: 1715, Hashed Watermarked Value: 45
# Unique Random Number: 9714, Hashed Watermarked Value: 989
# Unique Random Number: 9828, Hashed Watermarked Value: 3
# Unique Random Number: 9339, Hashed Watermarked Value: 289
# Unique Random Number: 9573, Hashed Watermarked Value: 911
# Unique Random Number: 2015, Hashed Watermarked Value: 735
# Unique Random Number: 5865, Hashed Watermarked Value: 657
# Unique Random Number: 9538, Hashed Watermarked Value: 385
# Unique Random Number: 9325, Hashed Watermarked Value: 340
# Unique Random Number: 2871, Hashed Watermarked Value: 665
# Unique Random Number: 5469, Hashed Watermarked Value: 488
# Unique Random Number: 551, Hashed Watermarked Value: 166
# Unique Random Number: 3551, Hashed Watermarked Value: 536
# Unique Random Number: 9938, Hashed Watermarked Value: 358
# Unique Random Number: 5988, Hashed Watermarked Value: 348
# Unique Random Number: 2451, Hashed Watermarked Value: 578
# Unique Random Number: 9213, Hashed Watermarked Value: 645
# Unique Random Number: 2714, Hashed Watermarked Value: 872
# Unique Random Number: 460, Hashed Watermarked Value: 831
# Unique Random Number: 4945, Hashed Watermarked Value: 206
# Unique Random Number: 1338, Hashed Watermarked Value: 904
# Unique Random Number: 7349, Hashed Watermarked Value: 276
# Unique Random Number: 9563, Hashed Watermarked Value: 47
# Unique Random Number: 953, Hashed Watermarked Value: 611
# Unique Random Number: 4372, Hashed Watermarked Value: 503
# Unique Random Number: 4030, Hashed Watermarked Value: 55
# Unique Random Number: 7980, Hashed Watermarked Value: 259
# Unique Random Number: 5932, Hashed Watermarked Value: 60
# Unique Random Number: 2734, Hashed Watermarked Value: 795
# Unique Random Number: 2166, Hashed Watermarked Value: 67
# Unique Random Number: 8729, Hashed Watermarked Value: 238
# Unique Random Number: 6608, Hashed Watermarked Value: 999
# Unique Random Number: 761, Hashed Watermarked Value: 618
# Unique Random Number: 8090, Hashed Watermarked Value: 3
# Unique Random Number: 1430, Hashed Watermarked Value: 348
# Unique Random Number: 2936, Hashed Watermarked Value: 275
# Unique Random Number: 5423, Hashed Watermarked Value: 633
# Unique Random Number: 8837, Hashed Watermarked Value: 367
# Unique Random Number: 1614, Hashed Watermarked Value: 108
# Unique Random Number: 787, Hashed Watermarked Value: 210
# Unique Random Number: 9985, Hashed Watermarked Value: 425
# Unique Random Number: 7567, Hashed Watermarked Value: 812
# Unique Random Number: 6173, Hashed Watermarked Value: 882
# Unique Random Number: 4762, Hashed Watermarked Value: 244
# Unique Random Number: 7010, Hashed Watermarked Value: 757
# Unique Random Number: 69, Hashed Watermarked Value: 985
# Unique Random Number: 6880, Hashed Watermarked Value: 950
# Unique Random Number: 2849, Hashed Watermarked Value: 365
# Unique Random Number: 5466, Hashed Watermarked Value: 484
# Unique Random Number: 3822, Hashed Watermarked Value: 472
# Unique Random Number: 846, Hashed Watermarked Value: 817
# Unique Random Number: 6085, Hashed Watermarked Value: 538
# Unique Random Number: 2100, Hashed Watermarked Value: 697
# Unique Random Number: 6816, Hashed Watermarked Value: 286
# Unique Random Number: 3243, Hashed Watermarked Value: 488
# Unique Random Number: 6829, Hashed Watermarked Value: 819
# Unique Random Number: 2441, Hashed Watermarked Value: 163
# Unique Random Number: 53, Hashed Watermarked Value: 952
# Unique Random Number: 6567, Hashed Watermarked Value: 456
# Unique Random Number: 27, Hashed Watermarked Value: 832
# Unique Random Number: 8658, Hashed Watermarked Value: 397
# Unique Random Number: 1987, Hashed Watermarked Value: 585
# Unique Random Number: 8726, Hashed Watermarked Value: 72
# Unique Random Number: 3760, Hashed Watermarked Value: 433
# Unique Random Number: 4850, Hashed Watermarked Value: 426
# Unique Random Number: 8147, Hashed Watermarked Value: 947
# Unique Random Number: 9266, Hashed Watermarked Value: 298
# Unique Random Number: 5480, Hashed Watermarked Value: 312
# Unique Random Number: 6276, Hashed Watermarked Value: 278
# Unique Random Number: 4950, Hashed Watermarked Value: 204
# Unique Random Number: 226, Hashed Watermarked Value: 136
# Unique Random Number: 8448, Hashed Watermarked Value: 293
# Unique Random Number: 9295, Hashed Watermarked Value: 172
# Unique Random Number: 6706, Hashed Watermarked Value: 264
# Unique Random Number: 3714, Hashed Watermarked Value: 204
# Unique Random Number: 2176, Hashed Watermarked Value: 787
# Unique Random Number: 9272, Hashed Watermarked Value: 120
# Unique Random Number: 9379, Hashed Watermarked Value: 400
# Unique Random Number: 3548, Hashed Watermarked Value: 262
# Unique Random Number: 1086, Hashed Watermarked Value: 560
# Unique Random Number: 2099, Hashed Watermarked Value: 801
# Unique Random Number: 3392, Hashed Watermarked Value: 499
# Unique Random Number: 3097, Hashed Watermarked Value: 989
# Unique Random Number: 7973, Hashed Watermarked Value: 150
# Unique Random Number: 6289, Hashed Watermarked Value: 725
# Unique Random Number: 196, Hashed Watermarked Value: 795
# Unique Random Number: 4920, Hashed Watermarked Value: 717
# Unique Random Number: 3144, Hashed Watermarked Value: 417
# Unique Random Number: 1979, Hashed Watermarked Value: 7
# Unique Random Number: 8251, Hashed Watermarked Value: 69
# Unique Random Number: 580, Hashed Watermarked Value: 281
# Unique Random Number: 7487, Hashed Watermarked Value: 593
# Unique Random Number: 2881, Hashed Watermarked Value: 937
# Unique Random Number: 8012, Hashed Watermarked Value: 765
# Unique Random Number: 899, Hashed Watermarked Value: 189
# Unique Random Number: 8163, Hashed Watermarked Value: 444
# Unique Random Number: 7905, Hashed Watermarked Value: 762
# Unique Random Number: 4474, Hashed Watermarked Value: 110
# Unique Random Number: 8835, Hashed Watermarked Value: 184
# Unique Random Number: 4645, Hashed Watermarked Value: 954
# Unique Random Number: 9151, Hashed Watermarked Value: 146
# Unique Random Number: 7127, Hashed Watermarked Value: 265
# Unique Random Number: 1942, Hashed Watermarked Value: 181
# Unique Random Number: 5254, Hashed Watermarked Value: 170
# Unique Random Number: 2761, Hashed Watermarked Value: 316
# Unique Random Number: 5762, Hashed Watermarked Value: 374
# Unique Random Number: 1307, Hashed Watermarked Value: 4
# Unique Random Number: 9475, Hashed Watermarked Value: 573
# Unique Random Number: 5328, Hashed Watermarked Value: 160
# Unique Random Number: 6687, Hashed Watermarked Value: 220
# Unique Random Number: 5387, Hashed Watermarked Value: 218
# Unique Random Number: 3227, Hashed Watermarked Value: 905
# Unique Random Number: 8332, Hashed Watermarked Value: 842
# Unique Random Number: 7137, Hashed Watermarked Value: 423
# Unique Random Number: 2490, Hashed Watermarked Value: 963
# Unique Random Number: 4672, Hashed Watermarked Value: 151
# Unique Random Number: 8583, Hashed Watermarked Value: 557
# Unique Random Number: 4178, Hashed Watermarked Value: 262
# Unique Random Number: 4973, Hashed Watermarked Value: 327
# Unique Random Number: 8587, Hashed Watermarked Value: 405
# Unique Random Number: 7325, Hashed Watermarked Value: 589
# Unique Random Number: 4867, Hashed Watermarked Value: 93
# Unique Random Number: 696, Hashed Watermarked Value: 199
# Unique Random Number: 1339, Hashed Watermarked Value: 962
# Unique Random Number: 821, Hashed Watermarked Value: 304
# Unique Random Number: 9564, Hashed Watermarked Value: 209
# Unique Random Number: 2917, Hashed Watermarked Value: 340
# Unique Random Number: 4156, Hashed Watermarked Value: 51
# Unique Random Number: 2082, Hashed Watermarked Value: 675
# Unique Random Number: 4008, Hashed Watermarked Value: 466
# Unique Random Number: 5059, Hashed Watermarked Value: 156
# Unique Random Number: 5490, Hashed Watermarked Value: 272
# Unique Random Number: 6005, Hashed Watermarked Value: 147
# Unique Random Number: 8553, Hashed Watermarked Value: 55
# Unique Random Number: 1215, Hashed Watermarked Value: 849
# Unique Random Number: 7670, Hashed Watermarked Value: 315
# Unique Random Number: 1713, Hashed Watermarked Value: 941
# Unique Random Number: 221, Hashed Watermarked Value: 341
# Unique Random Number: 6539, Hashed Watermarked Value: 200
# Unique Random Number: 743, Hashed Watermarked Value: 449
# Unique Random Number: 7080, Hashed Watermarked Value: 805
# Unique Random Number: 7400, Hashed Watermarked Value: 634
# Unique Random Number: 6899, Hashed Watermarked Value: 76
# Unique Random Number: 5685, Hashed Watermarked Value: 881
# Unique Random Number: 1433, Hashed Watermarked Value: 666
# Unique Random Number: 7231, Hashed Watermarked Value: 876
# Unique Random Number: 6399, Hashed Watermarked Value: 553
# Unique Random Number: 1093, Hashed Watermarked Value: 888
# Unique Random Number: 6112, Hashed Watermarked Value: 626
# Unique Random Number: 3894, Hashed Watermarked Value: 671
# Unique Random Number: 4344, Hashed Watermarked Value: 865
# Unique Random Number: 6162, Hashed Watermarked Value: 369
# Unique Random Number: 9856, Hashed Watermarked Value: 446
# Unique Random Number: 5550, Hashed Watermarked Value: 315
# Unique Random Number: 6915, Hashed Watermarked Value: 906
# Unique Random Number: 7202, Hashed Watermarked Value: 835
# Unique Random Number: 3423, Hashed Watermarked Value: 301
# Unique Random Number: 8942, Hashed Watermarked Value: 908
# Unique Random Number: 7109, Hashed Watermarked Value: 351
# Unique Random Number: 5977, Hashed Watermarked Value: 488
# Unique Random Number: 9816, Hashed Watermarked Value: 891
# Unique Random Number: 7007, Hashed Watermarked Value: 666
# Unique Random Number: 1401, Hashed Watermarked Value: 682
# Unique Random Number: 7566, Hashed Watermarked Value: 518
# Unique Random Number: 1764, Hashed Watermarked Value: 651
# Unique Random Number: 7489, Hashed Watermarked Value: 835
# Unique Random Number: 9262, Hashed Watermarked Value: 12
# Unique Random Number: 9124, Hashed Watermarked Value: 632
# Unique Random Number: 8388, Hashed Watermarked Value: 391
# Unique Random Number: 2071, Hashed Watermarked Value: 944
# Unique Random Number: 2945, Hashed Watermarked Value: 224
# Unique Random Number: 1999, Hashed Watermarked Value: 421
# Unique Random Number: 3788, Hashed Watermarked Value: 684
# Unique Random Number: 912, Hashed Watermarked Value: 254
# Unique Random Number: 1383, Hashed Watermarked Value: 19
# Unique Random Number: 5544, Hashed Watermarked Value: 67
# Unique Random Number: 313, Hashed Watermarked Value: 764
# Unique Random Number: 5402, Hashed Watermarked Value: 770
# Unique Random Number: 4352, Hashed Watermarked Value: 347
# Unique Random Number: 1637, Hashed Watermarked Value: 586
# Unique Random Number: 3013, Hashed Watermarked Value: 528
# Unique Random Number: 2773, Hashed Watermarked Value: 305
# Unique Random Number: 2873, Hashed Watermarked Value: 730
# Unique Random Number: 5855, Hashed Watermarked Value: 635
# Unique Random Number: 1404, Hashed Watermarked Value: 530
# Unique Random Number: 7622, Hashed Watermarked Value: 769
# Unique Random Number: 3464, Hashed Watermarked Value: 555
# Unique Random Number: 4294, Hashed Watermarked Value: 311
# Unique Random Number: 3582, Hashed Watermarked Value: 173
# Unique Random Number: 8179, Hashed Watermarked Value: 519
# Unique Random Number: 3900, Hashed Watermarked Value: 875
# Unique Random Number: 5640, Hashed Watermarked Value: 963
# Unique Random Number: 8784, Hashed Watermarked Value: 923
# Unique Random Number: 8619, Hashed Watermarked Value: 689
# Unique Random Number: 5380, Hashed Watermarked Value: 926
# Unique Random Number: 4274, Hashed Watermarked Value: 784
# Unique Random Number: 6303, Hashed Watermarked Value: 886
# Unique Random Number: 5917, Hashed Watermarked Value: 948
# Unique Random Number: 5255, Hashed Watermarked Value: 222
# Unique Random Number: 4303, Hashed Watermarked Value: 145
# Unique Random Number: 4744, Hashed Watermarked Value: 791
# Unique Random Number: 8333, Hashed Watermarked Value: 242
# Unique Random Number: 472, Hashed Watermarked Value: 418
# Unique Random Number: 9010, Hashed Watermarked Value: 715
# Unique Random Number: 5253, Hashed Watermarked Value: 393
# Unique Random Number: 7442, Hashed Watermarked Value: 962
# Unique Random Number: 3533, Hashed Watermarked Value: 694
# Unique Random Number: 7602, Hashed Watermarked Value: 731
# Unique Random Number: 4044, Hashed Watermarked Value: 854
# Unique Random Number: 1828, Hashed Watermarked Value: 758
# Unique Random Number: 6510, Hashed Watermarked Value: 500
# Unique Random Number: 3065, Hashed Watermarked Value: 811
# Unique Random Number: 5325, Hashed Watermarked Value: 496
# Unique Random Number: 2784, Hashed Watermarked Value: 381
# Unique Random Number: 3758, Hashed Watermarked Value: 438
# Unique Random Number: 2450, Hashed Watermarked Value: 742
# Unique Random Number: 8263, Hashed Watermarked Value: 456
# Unique Random Number: 6828, Hashed Watermarked Value: 956
# Unique Random Number: 5599, Hashed Watermarked Value: 285
# Unique Random Number: 4947, Hashed Watermarked Value: 82
# Unique Random Number: 9933, Hashed Watermarked Value: 548
# Unique Random Number: 9949, Hashed Watermarked Value: 21
# Unique Random Number: 915, Hashed Watermarked Value: 651
# Unique Random Number: 9956, Hashed Watermarked Value: 805
# Unique Random Number: 5206, Hashed Watermarked Value: 517
# Unique Random Number: 9881, Hashed Watermarked Value: 431
# Unique Random Number: 2393, Hashed Watermarked Value: 841
# Unique Random Number: 1706, Hashed Watermarked Value: 158
# Unique Random Number: 6012, Hashed Watermarked Value: 300
# Unique Random Number: 2469, Hashed Watermarked Value: 948
# Unique Random Number: 9947, Hashed Watermarked Value: 93
# Unique Random Number: 4507, Hashed Watermarked Value: 329
# Unique Random Number: 1805, Hashed Watermarked Value: 447
# Unique Random Number: 8354, Hashed Watermarked Value: 492
# Unique Random Number: 3608, Hashed Watermarked Value: 651
# Unique Random Number: 9565, Hashed Watermarked Value: 491
# Unique Random Number: 6811, Hashed Watermarked Value: 657
# Unique Random Number: 3719, Hashed Watermarked Value: 23
# Unique Random Number: 5577, Hashed Watermarked Value: 185
# Unique Random Number: 5819, Hashed Watermarked Value: 659
# Unique Random Number: 1782, Hashed Watermarked Value: 79
# Unique Random Number: 2885, Hashed Watermarked Value: 749
# Unique Random Number: 1279, Hashed Watermarked Value: 161
# Unique Random Number: 7911, Hashed Watermarked Value: 656
# Unique Random Number: 3338, Hashed Watermarked Value: 886
# Unique Random Number: 5321, Hashed Watermarked Value: 116
# Unique Random Number: 7459, Hashed Watermarked Value: 688
# Unique Random Number: 1092, Hashed Watermarked Value: 75
# Unique Random Number: 1653, Hashed Watermarked Value: 874
# Unique Random Number: 3875, Hashed Watermarked Value: 456
# Unique Random Number: 4440, Hashed Watermarked Value: 44
# Unique Random Number: 6419, Hashed Watermarked Value: 201
# Unique Random Number: 202, Hashed Watermarked Value: 944
# Unique Random Number: 1497, Hashed Watermarked Value: 617
# Unique Random Number: 6391, Hashed Watermarked Value: 840
# Unique Random Number: 1096, Hashed Watermarked Value: 260
# Unique Random Number: 868, Hashed Watermarked Value: 492
# Unique Random Number: 6302, Hashed Watermarked Value: 504
# Unique Random Number: 5633, Hashed Watermarked Value: 493
# Unique Random Number: 5800, Hashed Watermarked Value: 497
# Unique Random Number: 4148, Hashed Watermarked Value: 346
# Unique Random Number: 457, Hashed Watermarked Value: 660
# Unique Random Number: 5345, Hashed Watermarked Value: 523
# ...
# Group 1632: [{'birthMonth': '10', 'nationality': 'American', 'birthYear': '1960', 'name': 'Bharat Shah', 'countryOfResidence': 'United States'}, {'birthMonth': '9', 'nationality': 'American', 'birthYear': '1969', 'name': 'Victoria Ann Freeman', 'countryOfResidence': 'Usa'}, {'birthMonth': '8', 'nationality': 'American', 'birthYear': '1947', 'name': 'Michael S. Nutter', 'countryOfResidence': 'Usa'}, {'birthMonth': '8', 'nationality': 'American', 'birthYear': '1967', 'name': 'Dr. Dana Levi', 'countryOfResidence': 'England'}, {'birthMonth': '1', 'birthYear': '1985', 'nationality': 'Filipino,American', 'hashed_secret': 587, 'watermark_id': '6988'}]
# Group 1633: [{'birthMonth': '4', 'nationality': 'American', 'birthYear': '1967', 'name': 'Tracy Harvey', 'countryOfResidence': 'United States'}, {'birthMonth': '4', 'birthYear': '1927', 'nationality': 'American', 'hashed_secret': 578, 'watermark_id': '9854'}]
# Group 1634: [{'birthMonth': '11', 'nationality': 'American', 'birthYear': '1953', 'name': 'Mrs Martha Grossman', 'countryOfResidence': 'England'}, {'birthMonth': '4', 'nationality': 'American', 'birthYear': '1985', 'name': 'Cynthia Grace Best', 'countryOfResidence': 'England'}, {'birthMonth': '4', 'nationality': 'American', 'birthYear': '1962', 'name': 'Mrs Rebecca Jo Schaller', 'countryOfResidence': 'England'}, {'birthMonth': '9', 'nationality': 'American', 'birthYear': '1970', 'name': 'Stephen Charles Bishop', 'countryOfResidence': 'United States'}, {'birthMonth': '10', 'nationality': 'American', 'birthYear': '1969', 'name': 'Patricia Lynn Dayton', 'countryOfResidence': 'United States'}, {'birthMonth': '4', 'birthYear': '1981', 'nationality': 'German,American', 'hashed_secret': 35, 'watermark_id': '661'}]
# Group 1635: [{'birthMonth': '10', 'nationality': 'American', 'birthYear': '1972', 'name': 'Troy Dayton', 'countryOfResidence': 'United States'}, {'birthMonth': '4', 'nationality': 'American', 'birthYear': '1957', 'name': 'Ms Marianna Theresa Basile', 'countryOfResidence': 'United States'}, {'birthMonth': '6', 'birthYear': '1981', 'nationality': 'Irish/American', 'hashed_secret': 923, 'watermark_id': '288'}]
# Group 1636: [{'birthMonth': '9', 'nationality': 'American', 'birthYear': '1963', 'name': 'Dr Fadlo Khuri', 'countryOfResidence': 'United States'}, {'birthMonth': '4', 'nationality': 'American', 'birthYear': '1965', 'name': 'Mr Sean Campbell', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '7', 'nationality': 'American', 'birthYear': '1980', 'name': 'Mr Marc Ramsay Washington', 'countryOfResidence': 'United States'}, {'birthMonth': '5', 'nationality': 'American', 'birthYear': '1964', 'name': 'Thomas George Stanford', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'birthYear': '1938', 'nationality': 'Finnish,American', 'hashed_secret': 987, 'watermark_id': '988'}]
# Group 1637: [{'birthMonth': '2', 'nationality': 'American', 'birthYear': '1962', 'name': 'Mr Taylor Andrew Boutin', 'countryOfResidence': 'England'}, {'birthMonth': '8', 'nationality': 'American', 'birthYear': '1982', 'name': 'Mr Ryan Hoban', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '6', 'nationality': 'American', 'birthYear': '1972', 'name': 'Mr Stephen Steva Katanic', 'countryOfResidence': 'United States'}, {'birthMonth': '11', 'birthYear': '1960', 'nationality': 'African American', 'hashed_secret': 738, 'watermark_id': '6140'}]
# Group 1638: [{'birthMonth': '8', 'nationality': 'American', 'birthYear': '1970', 'name': 'Mr Todd Glider', 'countryOfResidence': 'Spain'}, {'birthMonth': '7', 'nationality': 'American', 'birthYear': '1982', 'name': 'Mr Jacob Plattner', 'countryOfResidence': 'United States'}, {'birthMonth': '10', 'birthYear': '1992', 'nationality': 'American,English', 'hashed_secret': 936, 'watermark_id': '9706'}]
# Group 1639: [{'birthMonth': '11', 'nationality': 'American', 'birthYear': '1940', 'name': 'Mr William Young', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1962', 'name': 'Mrs Janice Hobbs', 'countryOfResidence': 'England'}, {'birthMonth': '7', 'birthYear': '1986', 'nationality': 'American,Dutch', 'hashed_secret': 536, 'watermark_id': '5791'}]
# Group 1640: [{'birthMonth': '12', 'nationality': 'American', 'birthYear': '1958', 'name': 'Mr Jean Michel Guirao', 'countryOfResidence': 'United States'}, {'birthMonth': '4', 'nationality': 'American', 'birthYear': '1975', 'name': 'Mrs Lalitha Oruganti', 'countryOfResidence': 'England'}, {'birthMonth': '9', 'birthYear': '1929', 'nationality': 'United States Of American', 'hashed_secret': 130, 'watermark_id': '8761'}]
# Group 1641: [{'birthMonth': '5', 'nationality': 'American', 'birthYear': '1975', 'name': 'Mr Appal Chintapalli', 'countryOfResidence': 'England'}, {'birthMonth': '12', 'birthYear': '1942', 'nationality': 'American - Norwegian', 'hashed_secret': 891, 'watermark_id': '6218'}]
# Group 1642: [{'birthMonth': '2', 'nationality': 'American', 'birthYear': '1969', 'name': 'Mr Louis Scott Schwager', 'countryOfResidence': 'England'}, {'birthMonth': '9', 'nationality': 'American', 'birthYear': '1969', 'name': 'Mr Victor Petrone Jr', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '11', 'nationality': 'American', 'birthYear': '1960', 'name': 'Dr Adriana Corajoria Copeland', 'countryOfResidence': 'United States'}, {'birthMonth': '6', 'birthYear': '1997', 'nationality': 'American - Norwegian', 'hashed_secret': 194, 'watermark_id': '7318'}]
# Group 1648: [{'birthMonth': '8', 'nationality': 'German,American', 'birthYear': '1936', 'name': 'Fritz Rudolf Kundrun', 'countryOfResidence': 'United States'}, {'birthMonth': '1', 'nationality': 'British,American', 'birthYear': '1972', 'name': 'Ms Francesca Turner', 'countryOfResidence': 'England'}, {'birthMonth': '8', 'birthYear': '1961', 'nationality': 'American,French', 'hashed_secret': 42, 'watermark_id': '7756'}]
# Group 1649: [{'birthMonth': '6', 'nationality': 'American', 'birthYear': '1985', 'name': 'Mr Daniel Perez', 'countryOfResidence': 'England'}, {'birthMonth': '9', 'nationality': 'American', 'birthYear': '1965', 'name': 'Mrs Ann Joseph', 'countryOfResidence': 'England'}, {'birthMonth': '10', 'nationality': 'American', 'birthYear': '1986', 'name': 'Mr. Dean Dayal Boveja', 'countryOfResidence': 'United States'}, {'birthMonth': '8', 'birthYear': '1968', 'nationality': 'Chinese American', 'hashed_secret': 998, 'watermark_id': '3483'}]
# Group 1650: [{'birthMonth': '1', 'nationality': 'American', 'birthYear': '1985', 'name': 'Miss Naina Tara Boveja', 'countryOfResidence': 'United States'}, {'birthMonth': '8', 'nationality': 'American', 'birthYear': '1963', 'name': 'Mrs Suzanne Bari Buegel', 'countryOfResidence': 'England'}, {'birthMonth': '3', 'nationality': 'American', 'birthYear': '1957', 'name': 'Ms Jami Wintz Mckeon', 'countryOfResidence': 'United States'}, {'birthMonth': '3', 'birthYear': '1956', 'nationality': 'British And American', 'hashed_secret': 716, 'watermark_id': '2550'}]
# Group 1651: [{'birthMonth': '3', 'nationality': 'American', 'birthYear': '1953', 'name': 'Mr David Pollak', 'countryOfResidence': 'United States'}, {'birthMonth': '2', 'birthYear': '1971', 'nationality': 'Irish,American', 'hashed_secret': 608, 'watermark_id': '7352'}]
# Group 1652: [{'birthMonth': '5', 'nationality': 'American', 'birthYear': '1957', 'name': 'Mr Steven Wall', 'countryOfResidence': 'United States'}, {'birthMonth': '7', 'nationality': 'American', 'birthYear': '1973', 'name': 'Mr Anthony Licata', 'countryOfResidence': 'United States'}, {'birthMonth': '12', 'nationality': 'American', 'birthYear': '1963', 'name': 'Mr Steven Browne', 'countryOfResidence': 'United States'}, {'birthMonth': '6', 'nationality': 'American', 'birthYear': '1963', 'name': 'Mr John Charles Baxter Jr', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '10', 'nationality': 'French,American', 'birthYear': '1976', 'name': 'Mr Christopher Mathieu Esclapez', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '9', 'birthYear': '1992', 'nationality': 'Irish/American', 'hashed_secret': 244, 'watermark_id': '4301'}]
# Group 1653: [{'birthMonth': '3', 'nationality': 'American,Norwegian', 'birthYear': '1994', 'name': 'Katherine Kilnes', 'countryOfResidence': 'Bahamas'}, {'birthMonth': '5', 'birthYear': '1967', 'nationality': 'American - Norwegian', 'hashed_secret': 831, 'watermark_id': '4684'}]
# Group 1654: [{'birthMonth': '6', 'nationality': 'American', 'birthYear': '1961', 'name': 'Andrew Dean Katz', 'countryOfResidence': 'England'}, {'birthMonth': '11', 'birthYear': '1926', 'nationality': 'American,French', 'hashed_secret': 907, 'watermark_id': '2418'}]
OfResidence': 'England'}, {'birthMonth': '10', 'birthYear': '1948', 'nationality': 'American,Kenyan', 'hashed_secret': 123, 'watermark_id': '3571'}, {'birthMonth': '7', 'nationality': 'American', 'birthYear': '1989', 'name': 'Mr Steven Erich Hubbard', 'countryOfResidence': 'United States'}, {'birthMonth': '11', 'nationality': 'American', 'birthYear': '1968', 'name': 'Mr Michael James Nottingham', 'countryOfResidence': 'United Kingdom'}, {'birthMonth': '10', 'birthYear': '1965', 'nationality': 'British/American (Dual National)', 'hashed_secret': 662, 'watermark_id': '6072'}, {'birthMonth': '9', 'nationality': 'American', 'birthYear': '1967', 'name': 'Mr. Scott Moses', 'countryOfResidence': 'United States'}, {'birthMonth': '2', 'nationality': 'American', 'birthYear': '1971', 'name': "Mrs Courtney Ferester O'Grady", 'countryOfResidence': 'Scotland'}, {'birthMonth': '2', 'nationality': 'American', 'birthYear': '1974', 'name': 'Joanne Kinsella', 'countryOfResidence': 'United States'}, {'birthMonth': '5', 'nationality': 'American', 'birthYear': '1 ...

# %%
# Out:
# ^C
# Collecting embed
#   Downloading embed-0.3.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting infinity_emb==0.0.58 (from infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading infinity_emb-0.0.58-py3-none-any.whl.metadata (20 kB)
# Collecting hf_transfer>=0.1.5 (from infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading hf_transfer-0.1.8-cp312-none-win_amd64.whl.metadata (1.8 kB)
# Collecting huggingface_hub (from infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1.20.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.26.2)
# Collecting optimum>=1.16.2 (from optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading optimum-1.23.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pillow in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (10.3.0)
# Collecting sentence-transformers<4.0.0,>=3.0.1 (from infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Collecting soundfile<0.13.0,>=0.12.1 (from infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# Collecting timm (from infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading timm-1.0.11-py3-none-any.whl.metadata (48 kB)
# Collecting torch>=2.2.1 (from infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading torch-2.5.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting coloredlogs (from optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting sympy (from optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting transformers>=4.29 (from optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: packaging in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (24.1)
# Collecting datasets (from optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (3.12.4)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (6.0.1)
# Requirement already satisfied: requests in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (4.12.2)
# Collecting onnx (from optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading onnx-1.17.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting onnxruntime>=1.11.0 (from optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Collecting evaluate (from optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: protobuf>=3.20.1 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (5.28.3)
# Requirement already satisfied: scikit-learn in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers<4.0.0,>=3.0.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.5.1)
# Requirement already satisfied: scipy in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers<4.0.0,>=3.0.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.14.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from soundfile<0.13.0,>=0.12.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.16.0)
# Collecting networkx (from torch>=2.2.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.2.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.2.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (70.0.0)
# Collecting sympy (from optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting torchvision (from timm->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Collecting safetensors (from timm->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading safetensors-0.4.5-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: pycparser in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0->soundfile<0.13.0,>=0.12.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.22)
# Collecting pyarrow>=15.0.0 (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading pyarrow-18.1.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (0.3.7)
# Requirement already satisfied: pandas in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.2.3)
# Collecting tqdm>=4.42.1 (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (3.11.2)
# Collecting flatbuffers (from onnxruntime>=1.11.0->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->infinity_emb==0.0.58->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.29->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2023.10.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers>=4.29->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading tokenizers-0.20.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=2.2.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers<4.0.0,>=3.0.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers<4.0.0,>=3.0.1->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.17.1)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\neo_n\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets->optimum>=1.16.2->optimum[onnxruntime]>=1.16.2; extra == "optimum" or extra == "all"->infinity_emb[audio,optimum,torch,vision]==0.0.58->embed) (1.16.0)
# Downloading embed-0.3.0-py3-none-any.whl (4.7 kB)
# Downloading infinity_emb-0.0.58-py3-none-any.whl (80 kB)
# Downloading hf_transfer-0.1.8-cp312-none-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 10.0 MB/s eta 0:00:00
# Downloading optimum-1.23.3-py3-none-any.whl (424 kB)
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
# Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 16.2 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp312-cp312-win_amd64.whl (203.0 MB)
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#     --------------------------------------- 2.6/203.0 MB 13.7 MB/s eta 0:00:15
#     --------------------------------------- 5.0/203.0 MB 12.6 MB/s eta 0:00:16
#    - -------------------------------------- 7.9/203.0 MB 13.2 MB/s eta 0:00:15
#    -- ------------------------------------- 11.0/203.0 MB 13.0 MB/s eta 0:00:15
#    -- ------------------------------------- 13.6/203.0 MB 13.2 MB/s eta 0:00:15
#    --- ------------------------------------ 16.3/203.0 MB 13.1 MB/s eta 0:00:15
#    --- ------------------------------------ 19.1/203.0 MB 13.0 MB/s eta 0:00:15
#    ---- ----------------------------------- 22.3/203.0 MB 13.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 25.7/203.0 MB 13.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 29.4/203.0 MB 13.8 MB/s eta 0:00:13
#    ------ --------------------------------- 32.5/203.0 MB 14.0 MB/s eta 0:00:13
#    ------- -------------------------------- 35.9/203.0 MB 14.1 MB/s eta 0:00:12
#    ------- -------------------------------- 39.1/203.0 MB 14.2 MB/s eta 0:00:12
#    -------- ------------------------------- 41.4/203.0 MB 13.9 MB/s eta 0:00:12
#    -------- ------------------------------- 44.0/203.0 MB 13.9 MB/s eta 0:00:12
#    --------- ------------------------------ 46.9/203.0 MB 13.8 MB/s eta 0:00:12
#    --------- ------------------------------ 49.3/203.0 MB 13.8 MB/s eta 0:00:12
#    ---------- ----------------------------- 52.2/203.0 MB 13.7 MB/s eta 0:00:12
#    ---------- ----------------------------- 54.8/203.0 MB 13.6 MB/s eta 0:00:11
#    ----------- ---------------------------- 56.9/203.0 MB 13.5 MB/s eta 0:00:11
#    ----------- ---------------------------- 57.9/203.0 MB 13.5 MB/s eta 0:00:11
#    ----------- ---------------------------- 59.8/203.0 MB 13.1 MB/s eta 0:00:11
#    ----------- ----------------------------
MB 13.1 MB/s eta 0:00:02
#    ---------------------------------- ---- 181.9/203.0 MB 13.1 MB/s eta 0:00:02
#    ----------------------------------- --- 185.3/203.0 MB 13.1 MB/s eta 0:00:02
#    ------------------------------------ -- 188.7/203.0 MB 13.2 MB/s eta 0:00:02
#    ------------------------------------ -- 192.4/203.0 MB 13.2 MB/s eta 0:00:01
#    ------------------------------------- - 195.8/203.0 MB 13.3 MB/s eta 0:00:01
#    --------------------------------------  198.7/203.0 MB 13.3 MB/s eta 0:00:01
#    --------------------------------------  202.1/203.0 MB 13.3 MB/s eta 0:00:01
#    --------------------------------------  202.9/203.0 MB 13.3 MB/s eta 0:00:01
#    --------------------------------------- 203.0/203.0 MB 13.1 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------- ----------------- 3.4/6.2 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 16.5 MB/s eta 0:00:00
# Downloading timm-1.0.11-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.5 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading onnxruntime-1.20.1-cp312-cp312-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------ --------------------------- 3.4/11.3 MB 16.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.1/11.3 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 16.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 15.7 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/10.0 MB 12.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.0 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/10.0 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 13.6 MB/s eta 0:00:00
# Downloading safetensors-0.4.5-cp312-none-win_amd64.whl (286 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 15.7 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp312-cp312-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/14.5 MB 15.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.0/14.5 MB 14.7 MB/s eta 0:00:01
#    ------------------------- -------------- 9.2/14.5 MB 14.6 MB/s eta 0:00:01
#    --------------------------------- ------ 12.1/14.5 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 14.3 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 14.0 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    --------------------------------------- 536.2/536.2 kB 17.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading pyarrow-18.1.0-cp312-cp312-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ----- ---------------------------------- 3.4/25.1 MB 16.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.1/25.1 MB 16.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.7/25.1 MB 16.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.2/25.1 MB 16.5 MB/s eta 0:00:01
#    --------------------------- ------------ 17.6/25.1 MB 16.3 MB/s eta 0:00:01
#    --------------------------------- ------ 21.0/25.1 MB 16.6 MB/s eta 0:00:01
#    -------------------------------------- - 24.4/25.1 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 16.1 MB/s eta 0:00:00
# Downloading tokenizers-0.20.4-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 13.7 MB/s eta 0:00:00
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: mpmath, flatbuffers, xxhash, tqdm, sympy, safetensors, pyreadline3, pyarrow, onnx, networkx, hf_transfer, fsspec, dill, torch, soundfile, multiprocess, humanfriendly, huggingface_hub, torchvision, tokenizers, infinity_emb, coloredlogs, transformers, timm, onnxruntime, datasets, sentence-transformers, optimum, evaluate, embed
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.1
#     Uninstalling pyarrow-14.0.1:
#       Successfully uninstalled pyarrow-14.0.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
# Successfully installed coloredlogs-15.0.1 datasets-3.1.0 dill-0.3.8 embed-0.3.0 evaluate-0.4.3 flatbuffers-24.3.25 fsspec-2024.9.0 hf_transfer-0.1.8 huggingface_hub-0.26.2 humanfriendly-10.0 infinity_emb-0.0.58 mpmath-1.3.0 multiprocess-0.70.16 networkx-3.4.2 onnx-1.17.0 onnxruntime-1.20.1 optimum-1.23.3 pyarrow-18.1.0 pyreadline3-3.5.4 safetensors-0.4.5 sentence-transformers-3.3.1 soundfile-0.12.1 sympy-1.13.1 timm-1.0.11 tokenizers-0.20.4 torch-2.5.1 torchvision-0.20.1 tqdm-4.67.1 transformers-4.46.3 xxhash-3.5.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\neo_n\AppData\Local\Programs\Python\Python312\Lib\site-packages\~yarrow'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random
from faker import Faker
# from embed import *

# Initialize Faker for generating fake data
fake = Faker()

# Expanded lists for cities and occupations for fake data generation
cities = [
    "New York", "Los Angeles", "Chicago", "San Francisco", "Austin", "Boston", "Seattle", "Denver", "Miami",
    "Dallas", "Portland", "Houston", "Phoenix", "Philadelphia", "San Diego", "Atlanta", "Orlando", "Nashville"
]

occupations = [
    "Engineer", "Designer", "Artist", "Manager", "Consultant", "Chef", "Photographer", "Nurse",
    "Software Developer", "Researcher", "Teacher", "Architect", "Analyst", "Lawyer", "Musician",
    "Event Planner"
]

# Function to generate random data with 10% original data and 90% fake data
def create_random_data_with_real(num_entries, original_data, cities, occupations):
    random_data = []
    original_data_count = int(num_entries * 0.1)  # 10% of the data will be real
    fake_data_count = num_entries - original_data_count  # 90% will be fake

    # Add 10% real data
    for _ in range(original_data_count):
        real_entry = random.choice(original_data)
        random_data.append(real_entry)

    # Add 90% fake data
    for _ in range(fake_data_count):
        fake_entry = {
            "name": fake.first_name(),
            "age": random.randint(18, 60),
            "city": random.choice(cities),
            "occupation": random.choice(occupations),
            "salary": random.randint(40, 150) * 1000,  # Salary in thousands
            "married": random.choice([True, False]),
            "hobby": random.choice(["Photography", "Reading", "Traveling", "Cooking", "Hiking", "Gaming", "Dancing"])
        }
        random_data.append(fake_entry)

    return random_data

# Generate 10,000 randomized data entries mixing both fake and real data
randomized_data = create_random_data_with_real(1000, full_data, cities, occupations)

print(len(randomized_data))
# Print first 5 entries to check
for entry in randomized_data[:5]:  # print only the first 5 for brevity
    print(entry)


def validate_watermark_ids(records, id_list, private_key, watermark_identity, max_num_fields):
    # Convert id_list to a set for fast membership checks
    id_set = set(str(key) for key in id_list)  # Use set to avoid duplicates and improve lookup speed

    # Iterate over each record in the list with its index (record number)
    for index, record in enumerate(records):
        # Ensure the record has a 'watermark_id'
        if 'watermark_id' in record:
            watermark_id = str(record['watermark_id'])
            if watermark_id in id_set:
                record_hash = watermark_pseudo_node(record, private_key, str(watermark_id), [str(record["birthMonth"]), str(record["birthYear"])],
                                                    max_num_fields)

                # print("watermark_id", watermark_id)
                # print("generated hashed secret", record_hash["hashed_secret"])
                # print("expected hashed secret", id_list[int(watermark_id)])
                if record_hash['hashed_secret'] == id_list[int(watermark_id)]:
                    print("Valid watermark")
                    break
            else:
                print("No Valid watermark")


# Example usage
validate_watermark_ids(randomized_data, id_list, private_key, watermark_identity, max_num_fields)
# Out:
# 1000
# {'birthMonth': '1', 'nationality': 'American', 'birthYear': '1996', 'name': 'Ms Kimberly Abadir', 'countryOfResidence': 'United States'}
# {'birthMonth': '8', 'nationality': 'American', 'birthYear': '1979', 'name': 'Ms. Milcah E. Ferguson', 'countryOfResidence': 'United Kingdom'}
# {'birthMonth': '4', 'nationality': 'American', 'birthYear': '1974', 'name': 'Mr Eric Charles Degolier', 'countryOfResidence': 'United Kingdom'}
# {'birthMonth': '10', 'nationality': 'American', 'birthYear': '1973', 'name': 'Ms Lisa Buros', 'countryOfResidence': 'England'}
07307703', '09668044', '04241910', '04474739', '09880734', '10389673', '07710428', '10277136', '07690902', '09107663', '10277243', 'OC329755', '07299831', '07305986', '07305927', '00352801', '03490552', '07672981', '08603766', '05507007', '10277560', '10277562', '02732007', '08128718', 'NI032632', '10277825', '10277920', '10277925', 'NI639595', '10277969', '06949719', '10278081', '01599743', '10278208', '04332565', '10278246', '10278248', '09684102', '08270952', '10278445', '07300241', '09109097', '06640963', '05504998', '02729230', '10279119', '09117567', '08138283', '10279256', '08608021', '08143023', '06947952', '09119397', '10033569', '01755670', '07691698', '10279505', '08125858', '05521357', '08593714', '08555336', '06631894', '03828496', '09675491', '10279860', '10279943', '10280060', '10 ...

# %%
def validate_watermark_all(self, id_list, attributes):
        # Convert id_list to a set for fast membership checks
        id_set = set(str(key) for key in id_list)  # Use set to avoid duplicates and improve lookup speed
        pseudo_node_count = 0
        # Iterate over each record in the list with its index (record number)
        for index, record in enumerate(self.data):
            # Ensure the record has a 'watermark_id'
            if 'company_id' in record:
                watermark_id = str(record['company_id'])
                if watermark_id in id_set:
                    record_hash, hashed_secret_int = self.embed.watermark_pseudo_node(record, watermark_id,
                                                                                      "company_id",
                                                                                      attributes)
                    if hashed_secret_int == id_list[watermark_id]:
                        pseudo_node_count += 1

        return pseudo_node_count

# %%
def verify_watermark(data, id_list, private_key, watermark_identity, max_num_fields):
    """
    Return true if any record contains a valid watermark.
    """
    for record in data:
        if 'company_id' in record:
            valid_watermarks = validate_watermark_all([record], id_list, private_key, watermark_identity, max_num_fields)
            if valid_watermarks > 0:
                return True
    return False

# %%
def perform_deletion_attack(data, id_list, private_key, watermark_identity, max_num_fields, step=1):
    """
    Perform deletion attack while tracking valid watermarks.
    """
    total_records = len(data)
    deleted_nodes_percentage = []
    valid_watermarks_detected = []

    iterations = 0
    while data and verify_watermark(data, id_list, private_key, watermark_identity, max_num_fields):
        # Randomly delete `step` records
        for _ in range(step):
            if data:
                data.pop(random.randint(0, len(data) - 1))

        # Calculate the percentage of deleted nodes
        deleted_percentage = ((total_records - len(data)) / total_records) * 100
        deleted_nodes_percentage.append(deleted_percentage)

        # Validate watermarks in the remaining data
        valid_watermarks_records = validate_watermark_all(data, id_list, private_key, watermark_identity, max_num_fields)
        valid_watermarks_detected.append(valid_watermarks_records)  # Append here

        iterations += 1
        print(f"Iteration {iterations}: Remaining records = {len(data)}, Valid Watermarks Detected = {valid_watermarks_records}")

    print(f"Watermark verification failed after {iterations} iterations.")
    return deleted_nodes_percentage, valid_watermarks_detected

# Run the deletion attack
remaining_data = data.copy()  # To preserve the original dataset
deleted_nodes_percentage, valid_watermarks_detected = perform_deletion_attack(remaining_data, id_list, private_key, watermark_identity, max_num_fields, step=2)

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(deleted_nodes_percentage, valid_watermarks_detected, marker='o', color='b')

# Adding labels and title
plt.title('Effect of Deletion Attack on Valid Watermarks Detection')
plt.xlabel('Percentage of Deleted Nodes (%)')
plt.ylabel('Number of Valid Watermarks Detected')
plt.grid(True)
plt.show()
